# %%
#Import dependencies
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests

# %%
# Create a new set of 2,000 random latitudes and longitudes.
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# %%
# Add the latitudes and longitudes to a list. 
coordinates = list(coordinates)

# %%
# Create list for cities 
cities = []

# Get the nearest city using the citipy module.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 760

# %%
# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in our list.
for i in range(len(cities)):
    
   # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

   # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Run an API request for each of the cities.
    try:
       
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

# Append the city information into city_data list.
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
#If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | benghazi
# Processing Record 2 of Set 16 | sanchez
# Processing Record 3 of Set 16 | aleppo
# Processing Record 4 of Set 16 | ushuaia
# Processing Record 5 of Set 16 | bambous virieux
# Processing Record 6 of Set 16 | norman wells
# Processing Record 7 of Set 16 | albany
# Processing Record 8 of Set 16 | arraial do cabo
# Processing Record 9 of Set 16 | imeni poliny osipenko
# Processing Record 10 of Set 16 | ouro fino
# Processing Record 11 of Set 16 | butaritari
# Processing Record 12 of Set 16 | port alfred
# Processing Record 13 of Set 16 | boende
# Processing Record 14 of Set 16 | rikitea
# Processing Record 15 of Set 16 | prince rupert
# Processing Record 16 of Set 16 | sitka
# Processing Record 17 of Set 16 | jimeta
# Processing Record 18 of Set 16 | chuy
# Processing Record 19 of Set 16 | atuona
# Processing Record 20 of Set 16 | kapaa
# Processing Record 21 of Set 16 | santiago
# Processing Record 22 of Set 16 | vaini
# Processing Record 23 of Set 16 | hilo
# Processing Record 24 of Set 16 | salalah
# Processing Record 25 of Set 16 | mataura
# Processing Record 26 of Set 16 | saint george
# Processing Record 27 of Set 16 | kodiak
# Processing Record 28 of Set 16 | port-cartier
# Processing Record 29 of Set 16 | barrow
# Processing Record 30 of Set 16 | lebu
# Processing Record 31 of Set 16 | blonduos
# City not found. Skipping
# Processing Record 32 of Set 16 | castro
# Processing Record 33 of Set 16 | guerrero negro
# Processing Record 34 of Set 16 | tasbuget
# City not found. Skipping
# Processing Record 35 of Set 16 | pangnirtung
# Processing Record 36 of Set 16 | jamestown
# Processing Record 37 of Set 16 | labuhan
# Processing Record 38 of Set 16 | qaanaaq
# Processing Record 39 of Set 16 | taolanaro
# City not found. Skipping
# Processing Record 40 of Set 16 | airai
# Processing Record 41 of Set 16 | yar-sale
# Processing Record 42 of Set 16 | da nang
# Processing Record 43 of Set 16 | illoqqortoormiut
# City not found. Skipping
# Processing Record 44 of Set 16 | doha
# Processing Record 45 of Set 16 | cape town
# Processing Record 46 of Set 16 | provideniya
# Processing Record 47 of Set 16 | batagay
# Processing Record 48 of Set 16 | marabba
# Processing Record 49 of Set 16 | new norfolk
# Processing Record 50 of Set 16 | san quintin
# Processing Record 1 of Set 17 | klaksvik
# Processing Record 2 of Set 17 | mys shmidta
# City not found. Skipping
# Processing Record 3 of Set 17 | araouane
# Processing Record 4 of Set 17 | avarua
# Processing Record 5 of Set 17 | sinnamary
# Processing Record 6 of Set 17 | zaigrayevo
# Processing Record 7 of Set 17 | saint-philippe
# Processing Record 8 of Set 17 | ribeira grande
# Processing Record 9 of Set 17 | tsihombe
# City not found. Skipping
# Processing Record 10 of Set 17 | kaoma
# Processing Record 11 of Set 17 | cherskiy
# Processing Record 12 of Set 17 | kitimat
# Processing Record 13 of Set 17 | skjervoy
# Processing Record 14 of Set 17 | merauke
# Processing Record 15 of Set 17 | baripada
# Processing Record 16 of Set 17 | rosita
# Processing Record 17 of Set 17 | ponta do sol
# Processing Record 18 of Set 17 | yulara
# Processing Record 19 of Set 17 | joao pinheiro
# Processing Record 20 of Set 17 | yellowknife
# Processing Record 21 of Set 17 | punta arenas
# Processing Record 22 of Set 17 | vostok
# Processing Record 23 of Set 17 | karaul
# City not found. Skipping
# Processing Record 24 of Set 17 | gat
# Processing Record 25 of Set 17 | umm lajj
# Processing Record 26 of Set 17 | launceston
# Processing Record 27 of Set 17 | solana beach
# Processing Record 28 of Set 17 | college
# Processing Record 29 of Set 17 | mendahara
# City not found. Skipping
# Processing Record 30 of Set 17 | longyearbyen
# Processing Record 31 of Set 17 | holme
# Processing Record 32 of Set 17 | maumere
# Processing Record 33 of Set 17 | hoganas
# Processing Record 34 of Set 17 | hobart
# Processing Record 35 of Set 17 | bluff
# Processing Record 36 of Set 17 | darnah
# Processing Record 37 of Set 17 | taburi
# City not found. Skipping
# Processing Record 38 of Set 17 | port blair
# Processing Record 39 of Set 17 | inuvik
# Processing Record 40 of Set 17 | key west
# Processing Record 41 of Set 17 | ipixuna
# Processing Record 42 of Set 17 | te anau
# Processing Record 43 of Set 17 | nizhneyansk
# City not found. Skipping
# Processing Record 44 of Set 17 | meulaboh
# Processing Record 45 of Set 17 | bayan
# Processing Record 46 of Set 17 | hermanus
# Processing Record 47 of Set 17 | cedar city
# Processing Record 48 of Set 17 | guangshui
# Processing Record 49 of Set 17 | foix
# Processing Record 50 of Set 17 | sauteurs
# Processing Record 1 of Set 18 | belushya guba
# City not found. Skipping
# Processing Record 2 of Set 18 | mandali
# Processing Record 3 of Set 18 | georgetown
# Processing Record 4 of Set 18 | cabo san lucas
# Processing Record 5 of Set 18 | manta
# Processing Record 6 of Set 18 | santa rosa
# Processing Record 7 of Set 18 | westport
# Processing Record 8 of Set 18 | iqaluit
# Processing Record 9 of Set 18 | bredasdorp
# Processing Record 10 of Set 18 | beloha
# Processing Record 11 of Set 18 | severnyy
# Processing Record 12 of Set 18 | sloboda
# Processing Record 13 of Set 18 | matara
# Processing Record 14 of Set 18 | maniitsoq
# Processing Record 15 of Set 18 | waingapu
# Processing Record 16 of Set 18 | los llanos de aridane
# Processing Record 17 of Set 18 | busselton
# Processing Record 18 of Set 18 | letterkenny
# Processing Record 19 of Set 18 | avera
# Processing Record 20 of Set 18 | duluth
# Processing Record 21 of Set 18 | takoradi
# Processing Record 22 of Set 18 | tuatapere
# Processing Record 23 of Set 18 | mehran
# Processing Record 24 of Set 18 | karpogory
# Processing Record 25 of Set 18 | jiddah
# City not found. Skipping
# Processing Record 26 of Set 18 | narsaq
# Processing Record 27 of Set 18 | saskylakh
# Processing Record 28 of Set 18 | macaboboni
# City not found. Skipping
# Processing Record 29 of Set 18 | mangai
# Processing Record 30 of Set 18 | port elizabeth
# Processing Record 31 of Set 18 | dikson
# Processing Record 32 of Set 18 | centralia
# Processing Record 33 of Set 18 | manoel urbano
# Processing Record 34 of Set 18 | hammerfest
# Processing Record 35 of Set 18 | kloulklubed
# Processing Record 36 of Set 18 | souillac
# Processing Record 37 of Set 18 | nikolskoye
# Processing Record 38 of Set 18 | abha
# Processing Record 39 of Set 18 | rolim de moura
# City not found. Skipping
# Processing Record 40 of Set 18 | constantine
# Processing Record 41 of Set 18 | vestmannaeyjar
# Processing Record 42 of Set 18 | grindavik
# Processing Record 43 of Set 18 | berlevag
# Processing Record 44 of Set 18 | krotovka
# Processing Record 45 of Set 18 | saint anthony
# Processing Record 46 of Set 18 | olafsvik
# Processing Record 47 of Set 18 | namibe
# Processing Record 48 of Set 18 | kavieng
# Processing Record 49 of Set 18 | anzio
# Processing Record 50 of Set 18 | puerto ayora
# Processing Record 1 of Set 19 | rudbar
# Processing Record 2 of Set 19 | hami
# Processing Record 3 of Set 19 | jining
# Processing Record 4 of Set 19 | burica
# City not found. Skipping
# Processing Record 5 of Set 19 | bull savanna
# Processing Record 6 of Set 19 | pagudpud
# Processing Record 7 of Set 19 | marang
# Processing Record 8 of Set 19 | puro
# Processing Record 9 of Set 19 | esperance
# Processing Record 10 of Set 19 | tiznit
# Processing Record 11 of Set 19 | severo-kurilsk
# Processing Record 12 of Set 19 | saint-georges
# Processing Record 13 of Set 19 | tamuin
# Processing Record 14 of Set 19 | mahebourg
# Processing Record 15 of Set 19 | kavaratti
# Processing Record 16 of Set 19 | sentyabrskiy
# City not found. Skipping
# Processing Record 17 of Set 19 | codrington
# Processing Record 18 of Set 19 | sibu
# Processing Record 19 of Set 19 | paita
# Processing Record 20 of Set 19 | barkhan
# Processing Record 21 of Set 19 | tiksi
# Processing Record 22 of Set 19 | tromso
# Processing Record 23 of Set 19 | salaga
# Processing Record 24 of Set 19 | upernavik
# Processing Record 25 of Set 19 | yima
# Processing Record 26 of Set 19 | yelniki
# Processing Record 27 of Set 19 | coquimbo
# Processing Record 28 of Set 19 | bubaque
# Processing Record 29 of Set 19 | kieta
# Processing Record 30 of Set 19 | kamarion
# Processing Record 31 of Set 19 | east london
# Processing Record 32 of Set 19 | diamantino
# Processing Record 33 of Set 19 | vardo
# Processing Record 34 of Set 19 | olinda
# Processing Record 35 of Set 19 | ilulissat
# Processing Record 36 of Set 19 | razole
# Processing Record 37 of Set 19 | thompson
# Processing Record 38 of Set 19 | oster
# Processing Record 39 of Set 19 | padang
# Processing Record 40 of Set 19 | elko
# Processing Record 41 of Set 19 | chokurdakh
# Processing Record 42 of Set 19 | huicungo
# Processing Record 43 of Set 19 | bilibino
# Processing Record 44 of Set 19 | cidreira
# Processing Record 45 of Set 19 | inta
# Processing Record 46 of Set 19 | edmundston
# Processing Record 47 of Set 19 | malayal
# Processing Record 48 of Set 19 | ancud
# Processing Record 49 of Set 19 | sol-iletsk
# Processing Record 50 of Set 19 | bethel
# Processing Record 1 of Set 20 | khatanga
# Processing Record 2 of Set 20 | umba
# Processing Record 3 of Set 20 | quatre cocos
# Processing Record 4 of Set 20 | hithadhoo
# Processing Record 5 of Set 20 | ganzhou
# Processing Record 6 of Set 20 | sanpaul
# Processing Record 7 of Set 20 | sao filipe
# Processing Record 8 of Set 20 | torbay
# Processing Record 9 of Set 20 | talnakh
# Processing Record 10 of Set 20 | manuk mangkaw
# Processing Record 11 of Set 20 | dosso
# Processing Record 12 of Set 20 | laguna
# Processing Record 13 of Set 20 | cartagena
# Processing Record 14 of Set 20 | nome
# Processing Record 15 of Set 20 | ahipara
# Processing Record 16 of Set 20 | morwell
# Processing Record 17 of Set 20 | karakendzha
# City not found. Skipping
# Processing Record 18 of Set 20 | makinsk
# Processing Record 19 of Set 20 | tuktoyaktuk
# Processing Record 20 of Set 20 | najran
# Processing Record 21 of Set 20 | sao felix do xingu
# Processing Record 22 of Set 20 | wabag
# Processing Record 23 of Set 20 | juan aldama
# Processing Record 24 of Set 20 | smolenka
# Processing Record 25 of Set 20 | korla
# Processing Record 26 of Set 20 | lolua
# City not found. Skipping
# Processing Record 27 of Set 20 | canton
# Processing Record 28 of Set 20 | champerico
# Processing Record 29 of Set 20 | carnarvon
# Processing Record 30 of Set 20 | ulaangom
# Processing Record 31 of Set 20 | dauriya
# Processing Record 32 of Set 20 | rio brilhante
# Processing Record 33 of Set 20 | hihifo
# City not found. Skipping
# Processing Record 34 of Set 20 | zheleznodorozhnyy
# Processing Record 35 of Set 20 | kargasok
# Processing Record 36 of Set 20 | geraldton
# Processing Record 37 of Set 20 | oktyabrskiy
# Processing Record 38 of Set 20 | hasaki
# Processing Record 39 of Set 20 | kalianget
# Processing Record 40 of Set 20 | tubruq
# City not found. Skipping
# Processing Record 41 of Set 20 | xinmin
# Processing Record 42 of Set 20 | amderma
# City not found. Skipping
# Processing Record 43 of Set 20 | matay
# Processing Record 44 of Set 20 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 20 | san isidro
# Processing Record 46 of Set 20 | pevek
# Processing Record 47 of Set 20 | byron bay
# Processing Record 48 of Set 20 | muzquiz
# City not found. Skipping
# Processing Record 49 of Set 20 | den helder
# Processing Record 50 of Set 20 | constitucion
# Processing Record 1 of Set 21 | buin
# Processing Record 2 of Set 21 | visby
# Processing Record 3 of Set 21 | turukhansk
# Processing Record 4 of Set 21 | victoria
# Processing Record 5 of Set 21 | alihe
# Processing Record 6 of Set 21 | ortakoy
# Processing Record 7 of Set 21 | lapua
# Processing Record 8 of Set 21 | rosario
# Processing Record 9 of Set 21 | kaitangata
# Processing Record 10 of Set 21 | samalaeulu
# City not found. Skipping
# Processing Record 11 of Set 21 | palabuhanratu
# City not found. Skipping
# Processing Record 12 of Set 21 | balad
# Processing Record 13 of Set 21 | plougastel-daoulas
# Processing Record 14 of Set 21 | cedar lake
# Processing Record 15 of Set 21 | chemainus
# Processing Record 16 of Set 21 | mihara
# Processing Record 17 of Set 21 | grand river south east
# City not found. Skipping
# Processing Record 18 of Set 21 | qaqortoq
# Processing Record 19 of Set 21 | sakaiminato
# Processing Record 20 of Set 21 | warrnambool
# Processing Record 21 of Set 21 | fresnillo
# Processing Record 22 of Set 21 | poprad
# Processing Record 23 of Set 21 | chandauli
# Processing Record 24 of Set 21 | chapais
# Processing Record 25 of Set 21 | kotel
# Processing Record 26 of Set 21 | colares
# Processing Record 27 of Set 21 | iguape
# Processing Record 28 of Set 21 | kahului
# Processing Record 29 of Set 21 | cubara
# Processing Record 30 of Set 21 | palmerston north
# Processing Record 31 of Set 21 | monrovia
# Processing Record 32 of Set 21 | sopiste
# City not found. Skipping
# Processing Record 33 of Set 21 | sistranda
# Processing Record 34 of Set 21 | mentok
# City not found. Skipping
# Processing Record 35 of Set 21 | stornoway
# Processing Record 36 of Set 21 | attawapiskat
# City not found. Skipping
# Processing Record 37 of Set 21 | baruun-urt
# Processing Record 38 of Set 21 | mbandaka
# Processing Record 39 of Set 21 | hitoyoshi
# Processing Record 40 of Set 21 | buala
# Processing Record 41 of Set 21 | katherine
# Processing Record 42 of Set 21 | mazyr
# Processing Record 43 of Set 21 | touros
# Processing Record 44 of Set 21 | qandahar
# City not found. Skipping
# Processing Record 45 of Set 21 | ngukurr
# City not found. Skipping
# Processing Record 46 of Set 21 | grand gaube
# Processing Record 47 of Set 21 | andenes
# Processing Record 48 of Set 21 | juneau
# Processing Record 49 of Set 21 | zamberk
# Processing Record 50 of Set 21 | asau
# Processing Record 1 of Set 22 | ust-tsilma
# Processing Record 2 of Set 22 | yabelo
# Processing Record 3 of Set 22 | bandarbeyla
# Processing Record 4 of Set 22 | hambantota
# Processing Record 5 of Set 22 | montrose
# Processing Record 6 of Set 22 | santa cruz
# Processing Record 7 of Set 22 | kemi
# Processing Record 8 of Set 22 | tasiilaq
# Processing Record 9 of Set 22 | pontalina
# Processing Record 10 of Set 22 | lagoa
# Processing Record 11 of Set 22 | husavik
# Processing Record 12 of Set 22 | yeppoon
# Processing Record 13 of Set 22 | sinjar
# Processing Record 14 of Set 22 | diffa
# Processing Record 15 of Set 22 | bagdarin
# Processing Record 16 of Set 22 | istmina
# Processing Record 17 of Set 22 | lorengau
# Processing Record 18 of Set 22 | tarauaca
# Processing Record 19 of Set 22 | inhambane
# Processing Record 20 of Set 22 | srandakan
# Processing Record 21 of Set 22 | atambua
# Processing Record 22 of Set 22 | camana
# Processing Record 23 of Set 22 | bathsheba
# Processing Record 24 of Set 22 | caravelas
# Processing Record 25 of Set 22 | lompoc
# Processing Record 26 of Set 22 | clyde river
# Processing Record 27 of Set 22 | two rivers
# Processing Record 28 of Set 22 | salinopolis
# Processing Record 29 of Set 22 | leningradskiy
# Processing Record 30 of Set 22 | iringa
# Processing Record 31 of Set 22 | lensk
# Processing Record 32 of Set 22 | loandjili
# Processing Record 33 of Set 22 | karratha
# Processing Record 34 of Set 22 | calabazar de sagua
# Processing Record 35 of Set 22 | xuanwu
# Processing Record 36 of Set 22 | maragogi
# Processing Record 37 of Set 22 | mount gambier
# Processing Record 38 of Set 22 | port lincoln
# Processing Record 39 of Set 22 | kruisfontein
# Processing Record 40 of Set 22 | la ronge
# Processing Record 41 of Set 22 | hamilton
# Processing Record 42 of Set 22 | norden
# Processing Record 43 of Set 22 | morant bay
# Processing Record 44 of Set 22 | borovskoy
# Processing Record 45 of Set 22 | datong
# Processing Record 46 of Set 22 | barentsburg
# City not found. Skipping
# Processing Record 47 of Set 22 | xingcheng
# Processing Record 48 of Set 22 | brownwood
# Processing Record 49 of Set 22 | xiongyue
# Processing Record 50 of Set 22 | ostrovnoy
# Processing Record 1 of Set 23 | morehead
# Processing Record 2 of Set 23 | gay
# Processing Record 3 of Set 23 | paamiut
# Processing Record 4 of Set 23 | devils lake
# Processing Record 5 of Set 23 | broome
# Processing Record 6 of Set 23 | ylivieska
# Processing Record 7 of Set 23 | statesboro
# Processing Record 8 of Set 23 | shestakovo
# Processing Record 9 of Set 23 | pacific grove
# Processing Record 10 of Set 23 | taoudenni
# Processing Record 11 of Set 23 | mar del plata
# Processing Record 12 of Set 23 | baisha
# Processing Record 13 of Set 23 | miyang
# Processing Record 14 of Set 23 | tchollire
# Processing Record 15 of Set 23 | fortuna
# Processing Record 16 of Set 23 | nyagan
# Processing Record 17 of Set 23 | shingu
# Processing Record 18 of Set 23 | kormilovka
# Processing Record 19 of Set 23 | vanimo
# Processing Record 20 of Set 23 | samusu
# City not found. Skipping
# Processing Record 21 of Set 23 | rawson
# Processing Record 22 of Set 23 | maghama
# City not found. Skipping
# Processing Record 23 of Set 23 | ciudad bolivar
# Processing Record 24 of Set 23 | chapleau
# Processing Record 25 of Set 23 | jieznas
# Processing Record 26 of Set 23 | capitao poco
# Processing Record 27 of Set 23 | arman
# Processing Record 28 of Set 23 | houma
# Processing Record 29 of Set 23 | gorno-chuyskiy
# City not found. Skipping
# Processing Record 30 of Set 23 | luderitz
# Processing Record 31 of Set 23 | lata
# Processing Record 32 of Set 23 | buraydah
# Processing Record 33 of Set 23 | le port
# Processing Record 34 of Set 23 | rania
# Processing Record 35 of Set 23 | chateauroux
# Processing Record 36 of Set 23 | carbonia
# Processing Record 37 of Set 23 | kenai
# Processing Record 38 of Set 23 | pitimbu
# Processing Record 39 of Set 23 | biak
# Processing Record 40 of Set 23 | kupang
# Processing Record 41 of Set 23 | cayenne
# Processing Record 42 of Set 23 | port hawkesbury
# Processing Record 43 of Set 23 | naryan-mar
# Processing Record 44 of Set 23 | nuuk
# Processing Record 45 of Set 23 | hervey bay
# Processing Record 46 of Set 23 | zhangzhou
# Processing Record 47 of Set 23 | san patricio
# Processing Record 48 of Set 23 | sao joao da barra
# Processing Record 49 of Set 23 | kalisz
# Processing Record 50 of Set 23 | hovd
# Processing Record 1 of Set 24 | chikoy
# City not found. Skipping
# Processing Record 2 of Set 24 | balta
# Processing Record 3 of Set 24 | quartucciu
# Processing Record 4 of Set 24 | louisbourg
# City not found. Skipping
# Processing Record 5 of Set 24 | chernyanka
# Processing Record 6 of Set 24 | kutum
# Processing Record 7 of Set 24 | lazaro cardenas
# Processing Record 8 of Set 24 | kununurra
# Processing Record 9 of Set 24 | chicama
# Processing Record 10 of Set 24 | akyab
# Processing Record 11 of Set 24 | san pedro de los naranjos
# Processing Record 12 of Set 24 | thunder bay
# Processing Record 13 of Set 24 | fallon
# Processing Record 14 of Set 24 | ulladulla
# Processing Record 15 of Set 24 | banda aceh
# Processing Record 16 of Set 24 | eyl
# Processing Record 17 of Set 24 | dodge city
# Processing Record 18 of Set 24 | cieszyn
# Processing Record 19 of Set 24 | marilia
# Processing Record 20 of Set 24 | ust-kut
# Processing Record 21 of Set 24 | dhidhdhoo
# Processing Record 22 of Set 24 | laureles
# Processing Record 23 of Set 24 | blind river
# Processing Record 24 of Set 24 | paranhos
# Processing Record 25 of Set 24 | vanavara
# Processing Record 26 of Set 24 | dakoro
# Processing Record 27 of Set 24 | cockburn town
# Processing Record 28 of Set 24 | genhe
# Processing Record 29 of Set 24 | gizo
# Processing Record 30 of Set 24 | san cristobal
# Processing Record 31 of Set 24 | tura
# Processing Record 32 of Set 24 | erbaa
# Processing Record 33 of Set 24 | kamenskoye
# City not found. Skipping
# Processing Record 34 of Set 24 | roald
# Processing Record 35 of Set 24 | rorvik
# Processing Record 36 of Set 24 | fukiage
# Processing Record 37 of Set 24 | pervomayskiy
# Processing Record 38 of Set 24 | agva
# City not found. Skipping
# Processing Record 39 of Set 24 | sorland
# Processing Record 40 of Set 24 | praia da vitoria
# Processing Record 41 of Set 24 | pangkalanbuun
# Processing Record 42 of Set 24 | domoni
# Processing Record 43 of Set 24 | novichikha
# Processing Record 44 of Set 24 | tabuk
# Processing Record 45 of Set 24 | batemans bay
# Processing Record 46 of Set 24 | yaring
# Processing Record 47 of Set 24 | saldanha
# Processing Record 48 of Set 24 | ust-omchug
# Processing Record 49 of Set 24 | kazalinsk
# City not found. Skipping
# Processing Record 50 of Set 24 | natal
# Processing Record 1 of Set 25 | havelock
# Processing Record 2 of Set 25 | kidal
# Processing Record 3 of Set 25 | hirara
# Processing Record 4 of Set 25 | chaihe
# Processing Record 5 of Set 25 | tatawin
# Processing Record 6 of Set 25 | alappuzha
# Processing Record 7 of Set 25 | nantucket
# Processing Record 8 of Set 25 | veraval
# Processing Record 9 of Set 25 | barbar
# City not found. Skipping
# Processing Record 10 of Set 25 | minyar
# Processing Record 11 of Set 25 | honiara
# Processing Record 12 of Set 25 | kindu
# Processing Record 13 of Set 25 | nador
# Processing Record 14 of Set 25 | tomatlan
# Processing Record 15 of Set 25 | kulhudhuffushi
# Processing Record 16 of Set 25 | half moon bay
# Processing Record 17 of Set 25 | atbasar
# Processing Record 18 of Set 25 | mastic beach
# Processing Record 19 of Set 25 | muswellbrook
# Processing Record 20 of Set 25 | ormara
# Processing Record 21 of Set 25 | atoyac
# Processing Record 22 of Set 25 | marathon
# Processing Record 23 of Set 25 | penzance
# Processing Record 24 of Set 25 | roebourne
# Processing Record 25 of Set 25 | samana
# Processing Record 26 of Set 25 | deputatskiy
# Processing Record 27 of Set 25 | zhigansk
# Processing Record 28 of Set 25 | katsuura
# Processing Record 29 of Set 25 | kawalu
# Processing Record 30 of Set 25 | beira
# Processing Record 31 of Set 25 | bratsk
# Processing Record 32 of Set 25 | kalabo
# Processing Record 33 of Set 25 | turbat
# Processing Record 34 of Set 25 | kitaibaraki
# Processing Record 35 of Set 25 | taltal
# Processing Record 36 of Set 25 | jabiru
# City not found. Skipping
# Processing Record 37 of Set 25 | lasa
# Processing Record 38 of Set 25 | nieves
# Processing Record 39 of Set 25 | zlatoustovsk
# City not found. Skipping
# Processing Record 40 of Set 25 | seymchan
# Processing Record 41 of Set 25 | omboue
# Processing Record 42 of Set 25 | mount isa
# Processing Record 43 of Set 25 | porto santo
# Processing Record 44 of Set 25 | rutland
# Processing Record 45 of Set 25 | aguilas
# Processing Record 46 of Set 25 | homer
# Processing Record 47 of Set 25 | pakokku
# Processing Record 48 of Set 25 | dunedin
# Processing Record 49 of Set 25 | srednekolymsk
# Processing Record 50 of Set 25 | juifang
# City not found. Skipping
# Processing Record 1 of Set 26 | dingle
# Processing Record 2 of Set 26 | biloela
# Processing Record 3 of Set 26 | palmer
# Processing Record 4 of Set 26 | port hedland
# Processing Record 5 of Set 26 | bargal
# City not found. Skipping
# Processing Record 6 of Set 26 | norrtalje
# Processing Record 7 of Set 26 | kaeo
# Processing Record 8 of Set 26 | yafran
# Processing Record 9 of Set 26 | jinchengjiang
# City not found. Skipping
# Processing Record 10 of Set 26 | vega de alatorre
# Processing Record 11 of Set 26 | thinadhoo
# Processing Record 12 of Set 26 | sechura
# Processing Record 13 of Set 26 | savannah bight
# Processing Record 14 of Set 26 | lac du bonnet
# Processing Record 15 of Set 26 | nemuro
# Processing Record 16 of Set 26 | alekseyevka
# Processing Record 17 of Set 26 | sardarpur
# Processing Record 18 of Set 26 | nizhniy kuranakh
# Processing Record 19 of Set 26 | otjimbingwe
# Processing Record 20 of Set 26 | montepuez
# Processing Record 21 of Set 26 | bom jesus
# Processing Record 22 of Set 26 | yerbogachen
# Processing Record 23 of Set 26 | verkhovazhye
# Processing Record 24 of Set 26 | nha trang
# Processing Record 25 of Set 26 | rupert
# Processing Record 26 of Set 26 | alizai
# Processing Record 27 of Set 26 | samarai
# Processing Record 28 of Set 26 | vila do maio
# Processing Record 29 of Set 26 | okhotsk
# Processing Record 30 of Set 26 | carutapera
# Processing Record 31 of Set 26 | nanakuli
# Processing Record 32 of Set 26 | tifton
# Processing Record 33 of Set 26 | vestmanna
# Processing Record 34 of Set 26 | athabasca
# Processing Record 35 of Set 26 | boz
# Processing Record 36 of Set 26 | kanye
# Processing Record 37 of Set 26 | chagda
# City not found. Skipping
# Processing Record 38 of Set 26 | raga
# Processing Record 39 of Set 26 | floro
# Processing Record 40 of Set 26 | mogadishu
# Processing Record 41 of Set 26 | novopokrovka
# Processing Record 42 of Set 26 | pemangkat
# Processing Record 43 of Set 26 | axim
# Processing Record 44 of Set 26 | mangan
# Processing Record 45 of Set 26 | biltine
# Processing Record 46 of Set 26 | tigil
# Processing Record 47 of Set 26 | zhigalovo
# Processing Record 48 of Set 26 | medicine hat
# Processing Record 49 of Set 26 | jiayuguan
# Processing Record 50 of Set 26 | saint-augustin
# Processing Record 1 of Set 27 | tawkar
# City not found. Skipping
# Processing Record 2 of Set 27 | mokhsogollokh
# Processing Record 3 of Set 27 | beyneu
# Processing Record 4 of Set 27 | kwakoa
# Processing Record 5 of Set 27 | dakar
# Processing Record 6 of Set 27 | amuntai
# Processing Record 7 of Set 27 | makakilo city
# Processing Record 8 of Set 27 | hay river
# Processing Record 9 of Set 27 | shelburne
# Processing Record 10 of Set 27 | venice
# Processing Record 11 of Set 27 | grand centre
# City not found. Skipping
# Processing Record 12 of Set 27 | ambulu
# Processing Record 13 of Set 27 | vaitupu
# City not found. Skipping
# Processing Record 14 of Set 27 | kalmunai
# Processing Record 15 of Set 27 | esna
# Processing Record 16 of Set 27 | bengkulu
# Processing Record 17 of Set 27 | tacuarembo
# Processing Record 18 of Set 27 | vanderhoof
# Processing Record 19 of Set 27 | catuday
# Processing Record 20 of Set 27 | urumqi
# Processing Record 21 of Set 27 | kiama
# Processing Record 22 of Set 27 | tessalit
# Processing Record 23 of Set 27 | belmonte
# Processing Record 24 of Set 27 | bhadrachalam
# Processing Record 25 of Set 27 | vila franca do campo
# Processing Record 26 of Set 27 | mayo
# Processing Record 27 of Set 27 | valverde del camino
# Processing Record 28 of Set 27 | new richmond
# Processing Record 29 of Set 27 | longyan
# Processing Record 30 of Set 27 | north bend
# Processing Record 31 of Set 27 | karauzyak
# City not found. Skipping
# Processing Record 32 of Set 27 | malanje
# Processing Record 33 of Set 27 | umm kaddadah
# Processing Record 34 of Set 27 | chute-aux-outardes
# Processing Record 35 of Set 27 | port-gentil
# Processing Record 36 of Set 27 | alofi
# Processing Record 37 of Set 27 | sungaipenuh
# Processing Record 38 of Set 27 | warangal
# Processing Record 39 of Set 27 | ahuimanu
# Processing Record 40 of Set 27 | abu kamal
# Processing Record 41 of Set 27 | sidi ali
# Processing Record 42 of Set 27 | sambava
# Processing Record 43 of Set 27 | chitral
# Processing Record 44 of Set 27 | slave lake
# Processing Record 45 of Set 27 | tiarei
# Processing Record 46 of Set 27 | port hardy
# Processing Record 47 of Set 27 | poum
# Processing Record 48 of Set 27 | tottori
# Processing Record 49 of Set 27 | blackfoot
# Processing Record 50 of Set 27 | lavumisa
# Processing Record 1 of Set 28 | zyryanka
# Processing Record 2 of Set 28 | bonthe
# Processing Record 3 of Set 28 | athlone
# Processing Record 4 of Set 28 | ibra
# Processing Record 5 of Set 28 | saleaula
# City not found. Skipping
# Processing Record 6 of Set 28 | livingston
# Processing Record 7 of Set 28 | baykit
# Processing Record 8 of Set 28 | flinders
# Processing Record 9 of Set 28 | beringovskiy
# Processing Record 10 of Set 28 | naze
# Processing Record 11 of Set 28 | road town
# Processing Record 12 of Set 28 | vao
# Processing Record 13 of Set 28 | porto novo
# Processing Record 14 of Set 28 | la baule-escoublac
# Processing Record 15 of Set 28 | rungata
# City not found. Skipping
# Processing Record 16 of Set 28 | urdzhar
# City not found. Skipping
# Processing Record 17 of Set 28 | nadvoitsy
# Processing Record 18 of Set 28 | saint-francois
# Processing Record 19 of Set 28 | barawe
# City not found. Skipping
# Processing Record 20 of Set 28 | faanui
# Processing Record 21 of Set 28 | rocha
# Processing Record 22 of Set 28 | puerto cabezas
# Processing Record 23 of Set 28 | pundaguitan
# Processing Record 24 of Set 28 | richards bay
# Processing Record 25 of Set 28 | mahibadhoo
# Processing Record 26 of Set 28 | fort nelson
# Processing Record 27 of Set 28 | verkhnyaya inta
# Processing Record 28 of Set 28 | raudeberg
# Processing Record 29 of Set 28 | portland
# Processing Record 30 of Set 28 | demirci
# Processing Record 31 of Set 28 | krivopolyanye
# City not found. Skipping
# Processing Record 32 of Set 28 | hit
# Processing Record 33 of Set 28 | ketchikan
# Processing Record 34 of Set 28 | lumphat
# Processing Record 35 of Set 28 | vieste
# Processing Record 36 of Set 28 | marawi
# Processing Record 37 of Set 28 | ayan
# Processing Record 38 of Set 28 | lithgow
# Processing Record 39 of Set 28 | verkhnyaya toyma
# Processing Record 40 of Set 28 | tambopata
# Processing Record 41 of Set 28 | kropotkin
# Processing Record 42 of Set 28 | bereda
# Processing Record 43 of Set 28 | jackson
# Processing Record 44 of Set 28 | hinche
# Processing Record 45 of Set 28 | dodoma
# Processing Record 46 of Set 28 | wittmund
# Processing Record 47 of Set 28 | gamba
# Processing Record 48 of Set 28 | simi
# Processing Record 49 of Set 28 | muroto
# Processing Record 50 of Set 28 | marcona
# City not found. Skipping
# Processing Record 1 of Set 29 | hun
# Processing Record 2 of Set 29 | marzuq
# Processing Record 3 of Set 29 | malakal
# Processing Record 4 of Set 29 | volodarka
# Processing Record 5 of Set 29 | siverek
# Processing Record 6 of Set 29 | mabaruma
# Processing Record 7 of Set 29 | kemijarvi
# Processing Record 8 of Set 29 | denpasar
# Processing Record 9 of Set 29 | vryburg
# Processing Record 10 of Set 29 | aksu
# Processing Record 11 of Set 29 | komsomolskiy
# Processing Record 12 of Set 29 | lucea
# Processing Record 13 of Set 29 | minab
# Processing Record 14 of Set 29 | beidao
# Processing Record 15 of Set 29 | verkhnevilyuysk
# Processing Record 16 of Set 29 | morgan city
# Processing Record 17 of Set 29 | bilma
# Processing Record 18 of Set 29 | maloy
# Processing Record 19 of Set 29 | broken hill
# Processing Record 20 of Set 29 | morondava
# Processing Record 21 of Set 29 | camacupa
# Processing Record 22 of Set 29 | ensley
# Processing Record 23 of Set 29 | khandyga
# Processing Record 24 of Set 29 | mabay
# Processing Record 25 of Set 29 | margate
# Processing Record 26 of Set 29 | aykhal
# Processing Record 27 of Set 29 | hobyo
# Processing Record 28 of Set 29 | caibarien
# Processing Record 29 of Set 29 | skelleftea
# Processing Record 30 of Set 29 | mochudi
# Processing Record 31 of Set 29 | nago
# Processing Record 32 of Set 29 | boa vista
# Processing Record 33 of Set 29 | magway
# Processing Record 34 of Set 29 | santiago del estero
# Processing Record 35 of Set 29 | aksarka
# Processing Record 36 of Set 29 | san juan
# Processing Record 37 of Set 29 | svetlyy
# Processing Record 38 of Set 29 | erenhot
# Processing Record 39 of Set 29 | mitsamiouli
# Processing Record 40 of Set 29 | nkowakowa
# Processing Record 41 of Set 29 | puerto quijarro
# Processing Record 42 of Set 29 | shemonaikha
# Processing Record 43 of Set 29 | kottagudem
# Processing Record 44 of Set 29 | agadir
# Processing Record 45 of Set 29 | port moresby
# Processing Record 46 of Set 29 | fatick
# Processing Record 47 of Set 29 | chase
# Processing Record 48 of Set 29 | palencia
# Processing Record 49 of Set 29 | lar
# Processing Record 50 of Set 29 | udachnyy
# Processing Record 1 of Set 30 | mpika
# Processing Record 2 of Set 30 | vila velha
# Processing Record 3 of Set 30 | bonoua
# Processing Record 4 of Set 30 | dzhusaly
# City not found. Skipping
# Processing Record 5 of Set 30 | sipkovica
# Processing Record 6 of Set 30 | balabac
# Processing Record 7 of Set 30 | tezu
# Processing Record 8 of Set 30 | bukachacha
# Processing Record 9 of Set 30 | boksitogorsk
# Processing Record 10 of Set 30 | taburao
# City not found. Skipping
# Processing Record 11 of Set 30 | yurla
# Processing Record 12 of Set 30 | hualmay
# Processing Record 13 of Set 30 | kijang
# Processing Record 14 of Set 30 | levin
# Processing Record 15 of Set 30 | altar
# Processing Record 16 of Set 30 | talara
# Processing Record 17 of Set 30 | barentu
# Processing Record 18 of Set 30 | zafra
# Processing Record 19 of Set 30 | tangier
# Processing Record 20 of Set 30 | upata
# Processing Record 21 of Set 30 | mocuba
# Processing Record 22 of Set 30 | dukat
# Processing Record 23 of Set 30 | port augusta
# Processing Record 24 of Set 30 | sarnia
# Processing Record 25 of Set 30 | ilam
# Processing Record 26 of Set 30 | senador pompeu
# Processing Record 27 of Set 30 | manaure
# Processing Record 28 of Set 30 | sobradinho
# Processing Record 29 of Set 30 | wulanhaote
# City not found. Skipping
# Processing Record 30 of Set 30 | aklavik
# Processing Record 31 of Set 30 | rabo de peixe
# Processing Record 32 of Set 30 | yaan
# Processing Record 33 of Set 30 | ploemeur
# Processing Record 34 of Set 30 | novyy nekouz
# Processing Record 35 of Set 30 | roma
# Processing Record 36 of Set 30 | khuzdar
# Processing Record 37 of Set 30 | lima
# Processing Record 38 of Set 30 | acapulco
# Processing Record 39 of Set 30 | kayes
# Processing Record 40 of Set 30 | skagen
# Processing Record 41 of Set 30 | monopoli
# Processing Record 42 of Set 30 | nikki
# Processing Record 43 of Set 30 | skibbereen
# Processing Record 44 of Set 30 | santa luzia
# Processing Record 45 of Set 30 | pesaro
# Processing Record 46 of Set 30 | vaitape
# Processing Record 47 of Set 30 | imbituba
# Processing Record 48 of Set 30 | mehamn
# Processing Record 49 of Set 30 | san miguel
# Processing Record 50 of Set 30 | jalu
# Processing Record 1 of Set 31 | la dolorita
# Processing Record 2 of Set 31 | barra velha
# Processing Record 3 of Set 31 | zlitan
# Processing Record 4 of Set 31 | tahe
# Processing Record 5 of Set 31 | higuey
# City not found. Skipping
# Processing Record 6 of Set 31 | viligili
# City not found. Skipping
# Processing Record 7 of Set 31 | brejo da madre de deus
# Processing Record 8 of Set 31 | kegayli
# City not found. Skipping
# Processing Record 9 of Set 31 | bar harbor
# Processing Record 10 of Set 31 | camacha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Benghazi      LY  32.1167   20.0667     65.71        62
# 1                Sanchez      DO  19.2281  -69.6137     76.21        85
# 2                 Aleppo      SY  36.2500   37.5000     59.07        73
# 3                Ushuaia      AR -54.8000  -68.3000     35.26        75
# 4        Bambous Virieux      MU -20.3428   57.7575     73.65        83
# 5           Norman Wells      CA  65.2820 -126.8329     46.44        53
# 6                 Albany      US  42.6001  -73.9662     66.67        84
# 7        Arraial Do Cabo      BR -22.9661  -42.0278     71.20        71
# 8  Imeni Poliny Osipenko      RU  52.4201  136.4853     46.90        61
# 9              Ouro Fino      BR -22.2831  -46.3692     50.68        84
#
#    Cloudiness  Wind Speed Current Description
# 0           0        2.13           clear sky
# 1          22        6.15          few clouds
# 2           0       22.12           clear sky
# 3           0        4.61           clear sky
# 4          75        8.05       broken clouds
# 5         100        4.61     overcast clouds
# 6          99        1.99     overcast clouds
# 7           0       14.88           clear sky
# 8         100        7.45     overcast clouds
# 9           0        3.78           clear sky

# %%
# Create CSV file of DF
csv_weather_file = "Weatherpy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
